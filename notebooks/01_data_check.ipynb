# %% [markdown]
# # 数据检查
#
# 用于检查 URL、HTML、SQLite 和导出 CSV 的基础质量。

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
pd.read_csv(root / 'data' / 'raw' / 'fiba_game_urls.csv').head()
