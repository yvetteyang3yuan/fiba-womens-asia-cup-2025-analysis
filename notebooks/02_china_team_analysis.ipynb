# %% [markdown]
# # 中国女篮表现分析
#
# 基于全赛事数据，重点查看中国女篮比赛结果和球员表现。

# %%
from pathlib import Path
import pandas as pd

root = Path('..')
china_games = pd.read_csv(root / 'data' / 'clean' / 'china_games_summary.csv')
china_games
